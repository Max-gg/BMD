# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['tip'])

# %%
sns.jointplot(x='total_bill', y='tip', data = tips)

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'sex')

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-30752f89368e> in <module>
# ----> 1 sns.barplot(x='sex',y='total_bill',data=tips)
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3145             ax=None, **kwargs):
#    3146
# -> 3147     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
# -> 1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#    1618
#    1619         self.dodge = dodge
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in estimate_statistic(self, estimator, ci, n_boot, seed)
#    1514                     else:
#    1515
# -> 1516                         boots = bootstrap(stat_data, func=estimator,
#    1517                                           n_boot=n_boot,
#    1518                                           units=unit_data,
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in <listcomp>(.0)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# TypeError: Cannot cast array data from dtype('int64') to dtype('int32') according to the rule 'safe'

# %%
import numpy as np
sns.barplot(x = 'sex', y = 'total_bill', data = tips, estimator = np.median)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-7a3e2a58283a> in <module>
#       1 import numpy as np
# ----> 2 sns.barplot(x = 'sex', y = 'total_bill', data = tips, estimator = np.median)
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3145             ax=None, **kwargs):
#    3146
# -> 3147     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
# -> 1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#    1618
#    1619         self.dodge = dodge
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in estimate_statistic(self, estimator, ci, n_boot, seed)
#    1514                     else:
#    1515
# -> 1516                         boots = bootstrap(stat_data, func=estimator,
#    1517                                           n_boot=n_boot,
#    1518                                           units=unit_data,
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# c:\users\max25\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in <listcomp>(.0)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# TypeError: Cannot cast array data from dtype('int64') to dtype('int32') according to the rule 'safe'

# %%
sns.boxplot(x = 'day', y = 'tip', data = tips, palette = 'rainbow')

# %%
sns.stripplot(x = 'sex', y = 'tip', data = tips)

# %%
sns.heatmap(tips.corr())

# %%
g = sns.FacetGrid(tips, col="time", row="smoker")
g = g.map(plt.hist, "time")
